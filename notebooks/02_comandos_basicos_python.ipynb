# %% [markdown]
# <h1>Machine Learning e Python: Um Guia Prático
# à Ciência de Dados</h1>

# %% [markdown]
# <h3> Esse guia prático tem como objetivo o aprendizado de modo tradicional em machine learning, tudo feito aqui é seguindo o 1a edição do livro de
# 'Rodrigo Barbosa de Santis e
# Tiago Silveira Gontijo'.</h3>
